# %% [markdown]
# # Máximo

# %%
import numba 
from numba import cuda, jit, njit
import numpy as np
from functools import reduce
import datetime as dt
import matplotlib.pyplot as plt

def now():
    return dt.datetime.now()

with open('offline_1000000.csv', 'r', encoding='utf-8') as arq:
    array = np.array([int(i) for i in arq.read().split('\n') if i])
ref = max(array)
array.size, array.dtype, ref
# Out:
# (1000000, dtype('int64'), 10013464795)

# %%
@njit(parallel=True)
def maximo(array):
    return array.max()
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.001268039

# %%
@njit(parallel=True)
def maximo(array):
    return np.max(array)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.0012740059999999998

# %%
@njit(parallel=True)
def maximo(array):
    return np.amax(array)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.001279016

# %%
@jit
def maximo(array):
    maximum = 0
    for i in array:
        if i > maximum:
            maximum = i
    return maximum
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.002038467

# %%
@njit
def maximo(array):
    maximum = 0
    for i in array:
        if i > maximum:
            maximum = i
    return maximum
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.0021434839999999998

# %%
@njit
def maximo(array):
    maior = 0
    for i in array:
        if i > maior:
            maior = i
    return maior
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.002186003

# %%
@njit(parallel=True)
def maximo(array):
    maior = [0]
    for indice in numba.prange(len(array)):
        elem = array[indice]
        if  elem > maior[0]:
            maior[0] = elem
    return maior[0]
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.002257067

# %%
@njit
def maximo(array):
    return max(array)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.0022690410000000003

# %%
@njit(parallel=True)
def maximo(array):
    maximum = [0]
    for i in numba.prange(len(array)):
        if array[i] > maximum[0]:
            maximum[0] = array[i]
    return maximum[0]
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(m==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.0022779810000000005

# %%
@jit
def maximo(array):
    maior = 0
    for i in array:
        if i > maior:
            maior = i
    return maior
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.0022780110000000004

# %%
@jit(parallel=True)
def maximo(array):
    maior = [0]
    for indice in numba.prange(len(array)):
        elem = array[indice]
        if  elem > maior[0]:
            maior[0] = elem
    return maior[0]
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.002453025

# %%
def maximo(array):
    return np.max(array)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.0021789890000000005

# %%
@njit
def maximo(array):
    return np.amax(array)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.002216038

# %%
def maximo(array):
    return np.max(array)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.0022270550000000004

# %%
def maximo(array):
    return array.max()
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.0022929130000000006

# %%
@jit
def maximo(array):
    return array.max()
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.002320959

# %%
def maximo(array):
    return array.max()
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.002321688

# %%
@njit
def maximo(array):
    return np.max(array)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.002333026

# %%
@jit
def maximo(array):
    return np.amax(array)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.0023499980000000003

# %%
@njit
def maximo(array):
    return array.max()
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.0023619360000000007

# %%
@jit
def maximo(array):
    maior = [0]
    for indice in numba.prange(len(array)):
        elem = array[indice]
        if  elem > maior[0]:
            maior[0] = elem
    return maior[0]
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.002887982

# %%
@njit
def maximo(array):
    maior = [0]
    for indice in range(len(array)):
        elem = array[indice]
        if  elem > maior[0]:
            maior[0] = elem
    return maior[0]
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.002978

# %%
@jit
def maximo(array):
    return np.max(array)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.003211909

# %%
@cuda.jit()
def maximo0(array, max_gpu):
    local_max = max_gpu[1]
    for i in range(cuda.grid(1), array.shape[0], cuda.gridsize(1)):
        local_max = max(array[i], local_max)
    cuda.atomic.max(max_gpu, 0, local_max)

def maximo(array):
    array_gpu = cuda.to_device(array)
    max_gpu = cuda.to_device(np.zeros(1, dtype=np.float64))
    maximo0[1000, 1000](array_gpu, max_gpu)
    return max_gpu.copy_to_host()[0]
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.010592648999999999

# %%
@cuda.jit(fastmath=True)
def maximo0(array, max_gpu):
    local_max = max_gpu[1]
    for i in range(cuda.grid(1), array.shape[0], cuda.gridsize(1)):
        local_max = max(array[i], local_max)
    cuda.atomic.max(max_gpu, 0, local_max)
def maximo(array):
    array_gpu = cuda.to_device(array)
    max_gpu = cuda.to_device(np.zeros(1, dtype=np.float64))
    maximo0[1000, 1000](array_gpu, max_gpu)
    return max_gpu.copy_to_host()[0]
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.010984145999999998

# %%
@cuda.jit
def max_example(result, values):
    cuda.atomic.max(result, 0, values[(cuda.blockIdx.x * cuda.blockDim.x) + cuda.threadIdx.x])
def maximo(array):
    result = np.zeros(1, dtype=np.float64)
    raiz = int(len(array)**(1/2))
    max_example[raiz,raiz](result, array)
    return result[0]
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.013776975

# %%
@cuda.jit
def maxcudajit(result, values): 
    numba.cuda.atomic.max(result, 0, values[(cuda.blockIdx.x * cuda.blockDim.x) + cuda.threadIdx.x])
def maximo(array):
    result = np.zeros(1, dtype=np.float64)
    raiz = int(len(array)**(1/2))
    maxcudajit[raiz,raiz](result, array)
    return result[0]
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.013948761

# %%
@cuda.jit(fastmath=True)
def max_example(result, values):
    cuda.atomic.max(result, 0, values[(cuda.blockIdx.x * cuda.blockDim.x) + cuda.threadIdx.x])
def maximo(array):
    result = np.zeros(1, dtype=np.float64)
    raiz = int(len(array)**(1/2))
    max_example[raiz,raiz](result, array)
    return result[0]
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.013986583

# %%
@cuda.jit
def max_example(result, values):
    tid, bid, bdim = cuda.threadIdx.x, cuda.blockIdx.x, cuda.blockDim.x
    i = (bid * bdim) + tid
    cuda.atomic.max(result, 0, values[i])
def maximo(array):
    result = np.zeros(1, dtype=np.float64)
    raiz = int(len(array)**(1/2))
    max_example[raiz,raiz](result, array)
    return result[0]
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.014173954

# %%
@njit
def maximo(array):
    return  [array[i]  for i in range(len(array)) if array[i] > array[i-1]][-1]
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.016676851

# %%
@cuda.jit
def maximo1(result, values):
    tid, bid, bdim = cuda.threadIdx.x, cuda.blockIdx.x, cuda.blockDim.x
    i = (bid * bdim) + tid
    cuda.atomic.max(result, 0, values[i])

def maximo(array):
    result = np.zeros(1, dtype=np.float64)
    raiz = int(len(array)**(1/2))
    device_array = cuda.to_device(array)
    maximo1[raiz,raiz](result, array)
    return result[0]
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.020159011999999997

# %%
@jit
def maximo(array):
    maior = [0]
    return [maior.append(i) for i in array if i > maior[-1]][-1]
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# False 0.04761720099999999

# %%
@njit
def maximo(array):
    maior = [0]
    return [maior.append(i) for i in array if i > maior[-1]][-1]
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# False 0.047469243

# %%
def maximo(array):
    return max(array)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.16812090000000002

# %%
def maximo(array):
    return max(array)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.172939425

# %%
def maximo(array):
    maior = 0
    for i in array:
        if i > maior:
            maior = i
    return maior
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.21313723300000004

# %%
def maximo(array):
    maximum = 0
    for i in array:
        if i > maximum:
            maximum = i
    return maximum
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# True 0.22003515899999998

# %%
@jit
def maximo(a, b):
    return max(a, b)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-ee4a33157885> in <module>
#       5 for i in range(1000):
#       6     t0 = dt.datetime.now()
# ----> 7     m = maximo(array)
#       8     times.append((dt.datetime.now()-t0).total_seconds())
#       9 times = sorted(times)
#
# TypeError: not enough arguments: expected 2, got 1

# %%
@jit
def maximo(a, b):
    return max(a, b)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()

# %%
@njit
def maximo(a, b):
    return max(a, b)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()

# %%
@jit
def maximo(a, b):
    return max(a, b)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()

# %%
def maximo(a, b):
    return max(a, b)
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()

# %%
@jit
def maximo(array):
    maximum = 0
    for i in array:
        if i > maximum:
            maximum = i
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = maximo(array)
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(maximo(array)==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()

# %%
def maximo(a, b):
    return max([a, b])
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = reduce(maximo(array))
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(reduce(maximo(array))==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()

# %%
@jit
def maximo(a, b):
    return max([a, b])
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = reduce(maximo(array))
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(reduce(maximo(array))==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()

# %%
def maximo(a, b):
    return np.max([a, b])
times = []
for i in range(1000):
    t0 = dt.datetime.now()
    m = reduce(maximo(array))
    times.append((dt.datetime.now()-t0).total_seconds())
times = sorted(times)
media = np.average(times)
print(reduce(maximo(array))==ref, media)
plt.figure(figsize=(30,3))
plt.plot(times, label='Tempos')
plt.plot(len(times) *[media], label='Média')
plt.title('Média:' + str(media))
plt.legend()
plt.yscale('log')
plt.show()
